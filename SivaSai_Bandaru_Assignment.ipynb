# %%
# TASK 1 — Load Dataset

import pandas as pd

# Direct Google Drive download link
url = "https://drive.google.com/uc?id=1Mlu9r3afSGz5_02Y3wDJoQLpXszQXaIU"

# Load dataset with order_id as index
df = pd.read_csv(url, index_col="order_id")

print("Dataset Loaded Successfully ✅")

print("\nFirst 5 Rows:")
display(df.head())

print("\nLast 5 Rows:")
display(df.tail())
# Out:
# Dataset Loaded Successfully ✅
#
# First 5 Rows:
#           customer_name   product  quantity  unit_price  order_date     status
# order_id
# 1001      Alice Johnson    Laptop       1.0     85000.0  2024-01-15  delivered
# 1002          Bob Smith     Mouse       3.0       499.0  2024-01-16    pending
# 1003        Carol White   Monitor       2.0     15000.0         NaN  delivered
# 1004         Dave Brown  Keyboard       NaN      1200.0  2024-01-18  cancelled
# 1005          Eva Green    Laptop       1.0     85000.0  2024-01-19  delivered
# Last 5 Rows:
#          customer_name   product  quantity  unit_price  order_date     status
# order_id
# 1016       Paul Harris     Mouse       6.0       499.0  2024-01-30    pending
# 1017      Quinn Martin   Monitor       NaN     14500.0  2024-01-31  delivered
# 1018       Rachel King    Laptop       1.0     85000.0         NaN  delivered
# 1019        Sam Wright  Keyboard       3.0      1200.0  2024-02-01  cancelled
# ...

# %%
# TASK 2 — Structural Inspection

print("Dataset Shape:")
print(df.shape)

print("\nDataset Info:")
df.info()

print("\nMissing Values Per Column:")
print(df.isnull().sum())
# Out:
# Dataset Shape:
# (20, 6)
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, 1001 to 1020
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_name  20 non-null     object
#  1   product        20 non-null     object
#  2   quantity       16 non-null     float64
#  3   unit_price     20 non-null     float64
#  4   order_date     16 non-null     object
#  5   status         20 non-null     object
# dtypes: float64(2), object(4)
# memory usage: 1.1+ KB
#
# Missing Values Per Column:
# customer_name    0
# product          0
# quantity         4
# unit_price       0
# order_date       4
# status           0
# dtype: int64

# %% [markdown]
# ## TASK 2 — Answers
#
# ### 1️⃣ How many rows and columns does the dataset have?
#
# The dataset has:
# - **___ rows**
# - **___ columns**
#
# (Refer to df.shape output)
#
# ---
#
# ### 2️⃣ Which columns have missing values and how many?
#
# From df.isnull().sum():
#
# | Column Name | Missing Values |
# |------------|---------------|
# | ___ | ___ |
# | ___ | ___ |
#
# (Only list columns where missing values > 0)
#
# ---
#
# ### 3️⃣ Which column needs data type conversion before date analysis?
#
# The column that needs conversion is:
#
# **order_date**
#
# It is currently stored as type: **object**
#
# To convert it:
#
# ```python
# df["order_date"] = pd.to_datetime(df["order_date"])

# %%
# Convert order_date to datetime

df["order_date"] = pd.to_datetime(df["order_date"])

print("Updated Data Types:")
print(df.dtypes)
# Out:
# Updated Data Types:
# customer_name            object
# product                  object
# quantity                float64
# unit_price              float64
# order_date       datetime64[ns]
# status                   object
# dtype: object

# %%
# TASK 3 — Statistical Summary

print("Statistical Summary:")
display(df.describe())

print("\nMedian Unit Price:")
print(df["unit_price"].median())

print("\nSkewness of Unit Price:")
print(df["unit_price"].skew())

# %% [markdown]
# ## TASK 3 — Answers
#
# ### 1️⃣ What is the median unit_price?
#
# Median unit_price = ₹ ______
#
# (Refer to 50% value in df.describe() OR df["unit_price"].median())
#
# ---
#
# ### 2️⃣ Does unit_price appear to be skewed?
#
# Compare:
#
# - Mean = ₹ ______
# - Median = ₹ ______
# - Skewness = ______
#
# If mean > median and skewness > 0 → Positively skewed (right skew)
#
# If mean < median and skewness < 0 → Negatively skewed (left skew)
#
# Conclusion:
#
# The unit_price distribution appears to be **__________ skewed** because __________.
